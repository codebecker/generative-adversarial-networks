# %% [markdown]
# <a href="https://colab.research.google.com/github/codebecker/generative-adversarial-networks/blob/main/fmnist_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir input
# !mkdir outputs

# %%
# %%writefile vanilla_gan.py
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.datasets as datasets
import imageio
import numpy as np
import matplotlib

from torchvision.utils import make_grid, save_image
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
from tqdm import tqdm

matplotlib.style.use('ggplot')

# learning parameters
batch_size = 512
epochs = 200
sample_size = 64 # fixed sample size
nz = 128 # latent vector size
k = 1 # number of steps to apply to the discriminator
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize((0.5,),(0.5,)),
])

to_pil_image = transforms.ToPILImage()

train_data = datasets.FashionMNIST(
    root='input/data',
    train=True,
    download=True,
    transform=transform
)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

class Generator(nn.Module):
    def __init__(self, nz):
        super(Generator, self).__init__()
        self.nz = nz
        self.main = nn.Sequential(
            nn.Linear(self.nz, 256),
            nn.LeakyReLU(0.2),

            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),

            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),

            nn.Linear(1024, 784),
            nn.Tanh(),
        )

    def forward(self, x):
        return self.main(x).view(-1, 1, 28, 28)

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.n_input = 784
        self.main = nn.Sequential(
            nn.Linear(self.n_input, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),

            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),

            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        x = x.view(-1, 784)
        return self.main(x)

generator = Generator(nz).to(device)
discriminator = Discriminator().to(device)

print('##### GENERATOR #####')
print(generator)
print('######################')

print('\n##### DISCRIMINATOR #####')
print(discriminator)
print('######################')

# optimizers
optim_g = optim.Adam(generator.parameters(), lr=0.0002)
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002)

# loss function
criterion = nn.BCELoss() #binary cross entropy

losses_g = [] # to store generator loss after each epoch
losses_d = [] # to store discriminator loss after each epoch
images = [] # to store images generatd by the generator

# to create real labels (1s)
def label_real(size):
    data = torch.ones(size, 1)
    return data.to(device)

# to create fake labels (0s)
def label_fake(size):
    data = torch.zeros(size, 1)
    return data.to(device)

# function to create the noise vector
def create_noise(sample_size, nz):
    return torch.randn(sample_size, nz).to(device)

# to save the images generated by the generator
def save_generator_image(image, path):
    save_image(image, path)

# function to train the discriminator network
def train_discriminator(optimizer, data_real, data_fake):
    b_size = data_real.size(0)
    real_label = label_real(b_size)
    fake_label = label_fake(b_size)

    optimizer.zero_grad()

    output_real = discriminator(data_real)
    loss_real = criterion(output_real, real_label)

    output_fake = discriminator(data_fake)
    loss_fake = criterion(output_fake, fake_label)


    loss_real.backward()
    loss_fake.backward()
    optimizer.step()

    return loss_real + loss_fake

# function to train the generator network
def train_generator(optimizer, data_fake):
    b_size = data_fake.size(0)
    real_label = label_real(b_size)

    optimizer.zero_grad()

    output = discriminator(data_fake)
    loss = criterion(output, real_label)

    loss.backward()
    optimizer.step()

    return loss    

# create the noise vector
noise = create_noise(sample_size, nz)

generator.train()
discriminator.train()

for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):
        image, _ = data
        image = image.to(device)
        b_size = len(image)
        # run the discriminator for k number of steps
        for step in range(k):
            data_fake = generator(create_noise(b_size, nz)).detach()
            data_real = image
            # train the discriminator network
            loss_d += train_discriminator(optim_d, data_real, data_fake)
        data_fake = generator(create_noise(b_size, nz))
        # train the generator network
        loss_g += train_generator(optim_g, data_fake)

    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    # make the images as grid
    generated_img = make_grid(generated_img)
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"outputs/gen_img{epoch}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")

print('DONE TRAINING')
torch.save(generator.state_dict(), 'outputs/generator.pth')

# save the generated images as GIF file
imgs = [np.array(to_pil_image(img)) for img in images]
imageio.mimsave('outputs/generator_images.gif', imgs)

# plot and save the generator and discriminator loss
plt.figure()
plt.plot(losses_g, label='Generator loss')
plt.plot(losses_d, label='Discriminator Loss')
plt.legend()
plt.savefig('outputs/loss.png')
# Out:
# Writing vanilla_gan.py

# %%
# !python vanilla_gan.py
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to input/data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 26422272it [00:01, 18351421.42it/s]
# Extracting input/data/FashionMNIST/raw/train-images-idx3-ubyte.gz to input/data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to input/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 29696it [00:00, 339514.78it/s]
# Extracting input/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to input/data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to input/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 4422656it [00:00, 6224673.83it/s]
# Extracting input/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to input/data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to input/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 6144it [00:00, 14253210.05it/s]
# Extracting input/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to input/data/FashionMNIST/raw
#
# Processing...
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:502: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!
# ##### GENERATOR #####
# Generator(
#   (main): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2)
#     (4): Linear(in_features=512, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.2)
#     (6): Linear(in_features=1024, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )
# ######################
#
# ##### DISCRIMINATOR #####
# Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Dropout(p=0.3, inplace=False)
#     (9): Linear(in_features=256, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )
# ######################
# 118it [00:08, 14.33it/s]
# Epoch 0 of 200
# Generator loss: 1.31001151, Discriminator loss: 0.98040420
# 118it [00:07, 14.85it/s]
# Epoch 1 of 200
# Generator loss: 1.55860984, Discriminator loss: 0.81360215
# 118it [00:08, 14.68it/s]
# Epoch 2 of 200
# Generator loss: 2.24850440, Discriminator loss: 0.50432342
# 118it [00:07, 15.14it/s]
# Epoch 3 of 200
# Generator loss: 3.88534975, Discriminator loss: 0.91659856
# 118it [00:07, 14.89it/s]
# Epoch 4 of 200
# Generator loss: 6.28588676, Discriminator loss: 0.60299379
# 118it [00:08, 14.58it/s]
# Epoch 5 of 200
# Generator loss: 4.86458635, Discriminator loss: 0.32712284
# 118it [00:08, 14.65it/s]
# Epoch 6 of 200
# Generator loss: 3.89876080, Discriminator loss: 0.45910621
# 118it [00:07, 14.81it/s]
# Epoch 7 of 200
# Generator loss: 4.49398899, Discriminator loss: 0.58345824
# 118it [00:08, 14.54it/s]
# Epoch 8 of 200
# Generator loss: 3.94556165, Discriminator loss: 0.62726152
# 118it [00:08, 14.52it/s]
# Epoch 9 of 200
# Generator loss: 3.04580426, Discriminator loss: 0.61402583
# 118it [00:07, 14.80it/s]
# Epoch 10 of 200
# 118it [00:07, 15.32it/s]
# Epoch 92 of 200
# Generator loss: 2.07823777, Discriminator loss: 0.73472655
# 118it [00:07, 15.05it/s]
# Epoch 93 of 200
# Generator loss: 2.04291987, Discriminator loss: 0.70037776
# 118it [00:07, 15.41it/s]
# Epoch 94 of 200
# Generator loss: 2.12176013, Discriminator loss: 0.69820845
# 118it [00:07, 15.42it/s]
# Epoch 95 of 200
# Generator loss: 2.05398488, Discriminator loss: 0.69980228
# 118it [00:07, 15.38it/s]
# Epoch 96 of 200
# Generator loss: 2.05894327, Discriminator loss: 0.75132585
# 118it [00:07, 15.13it/s]
# Epoch 97 of 200
# Generator loss: 1.96939111, Discriminator loss: 0.75426495
# 118it [00:07, 15.25it/s]
# Epoch 98 of 200
# Generator loss: 1.94461942, Discriminator loss: 0.75822437
# 118it [00:07, 15.50it/s]
# Epoch 99 of 200
# Generator loss: 2.05322123, Discriminator loss: 0.69540232
# 118it [00:07, 15.53it/s]
# Epoch 100 of 200
# Generator loss: 1.99462569, Discriminator loss: 0.75437278
# 118it [00:07, 15.27it/s]
# Epoch 101 of 200
# Generator loss: 1.95737362, Discriminator loss: 0.76542306
# 118it [00:08, 14.72it/s]
# Epoch 102 of 200
# Generator loss: 1.96446693, Discriminator loss: 0.72857827
# 118it [00:07, 15.12it/s]
# Epoch 103 of 200
# Generator loss: 2.05878448, Discriminator loss: 0.71787393
# 118it [00:07, 15.16it/s]
# Epoch 104 of 200
# Generator loss: 1.88228655, Discriminator loss: 0.73597509
# 118it [00:07, 15.50it/s]
# Epoch 105 of 200
# Generator loss: 2.02367091, Discriminator loss: 0.74267334
# 118it [00:07, 15.09it/s]
# Epoch 106 of 200
# Generator loss: 1.96375608, Discriminator loss: 0.75610685
# 118it [00:07, 15.51it/s]
# Epoch 107 of 200
# Generator loss: 1.83393991, Discriminator loss: 0.77750289
# 118it [00:07, 15.44it/s]
# Epoch 108 of 200
# Generator loss: 1.84778249, Discriminator loss: 0.76823092
# 118it [00:07, 15.08it/s]
# Epoch 109 of 200
# Generator loss: 1.89092898, Discriminator loss: 0.73598254
# 118it [00:07, 15.34it/s]
# Epoch 110 of 200
# Generator loss: 1.95464051, Discriminator loss: 0.74640864
# 118it [00:07, 15.11it/s]
# Epoch 111 of 200
# Generator loss: 1.85622418, Discriminator loss: 0.76065606
# 118it [00:07, 15.20it/s]
# Epoch 112 of 200
# Generator loss: 1.92239094, Discriminator loss: 0.75439751
# 118it [00:07, 15.51it/s]
# Epoch 113 of 200
# Generator loss: 1.72941172, Discriminator loss: 0.83000416
# 118it [00:07, 15.06it/s]
# Epoch 114 of 200
# Generator loss: 1.99525738, Discriminator loss: 0.73292345
# 118it [00:07, 15.07it/s]
# Epoch 115 of 200
# Generator loss: 1.81287098, Discriminator loss: 0.81173170
# 118it [00:07, 15.55it/s]
# Epoch 116 of 200
# Generator loss: 1.82621884, Discriminator loss: 0.76214528
# 118it [00:07, 15.30it/s]
# Epoch 117 of 200
# Generator loss: 1.82005858, Discriminator loss: 0.78149348
# 118it [00:07, 15.39it/s]
# Epoch 118 of 200
# Generator loss: 1.81571972, Discriminator loss: 0.78661019
# 118it [00:07, 15.19it/s]
# Epoch 119 of 200
# Generator loss: 1.79071617, Discriminator loss: 0.82297826
# 118it [00:07, 15.32it/s]
# Epoch 120 of 200
# Generator loss: 1.83732593, Discriminator loss: 0.78713214
# 118it [00:07, 15.58it/s]
# Epoch 121 of 200
# Generator loss: 1.86674178, Discriminator loss: 0.76308000
# 118it [00:07, 15.28it/s]
# Epoch 122 of 200
# Generator loss: 1.73836660, Discriminator loss: 0.77628481
# 118it [00:07, 15.19it/s]
# Epoch 123 of 200
# Generator loss: 1.85200369, Discriminator loss: 0.75365937
# 118it [00:07, 15.19it/s]
# Epoch 124 of 200
# Generator loss: 1.95450950, Discriminator loss: 0.72651178
# 118it [00:07, 15.20it/s]
# Epoch 125 of 200
# Generator loss: 1.80779386, Discriminator loss: 0.79569072
# 118it [00:07, 15.37it/s]
# Epoch 126 of 200
# Generator loss: 1.85957992, Discriminator loss: 0.76499403
# 118it [00:07, 15.09it/s]
# Epoch 127 of 200
# Generator loss: 1.78621984, Discriminator loss: 0.78180724
# 118it [00:07, 15.17it/s]
# Epoch 128 of 200
# Generator loss: 1.82634795, Discriminator loss: 0.78883988
# 118it [00:07, 15.36it/s]
# Epoch 129 of 200
# Generator loss: 1.87431777, Discriminator loss: 0.80644417
# 118it [00:07, 15.35it/s]
# Epoch 130 of 200
# Generator loss: 1.79436946, Discriminator loss: 0.81516361
# 118it [00:07, 15.47it/s]
# Epoch 131 of 200
# Generator loss: 1.75146961, Discriminator loss: 0.79585689
# 118it [00:07, 15.33it/s]
# Epoch 132 of 200
# Generator loss: 1.79632580, Discriminator loss: 0.78145540
# 118it [00:07, 15.09it/s]
# Epoch 133 of 200
# Generator loss: 1.82661736, Discriminator loss: 0.77306557
# 118it [00:07, 15.48it/s]
# Epoch 134 of 200
# Generator loss: 1.83803022, Discriminator loss: 0.81530970
# 118it [00:07, 15.28it/s]
# Epoch 135 of 200
# Generator loss: 1.78028262, Discriminator loss: 0.81852525
# 118it [00:07, 15.20it/s]
# Epoch 136 of 200
# Generator loss: 1.71939421, Discriminator loss: 0.80825049
# 118it [00:07, 15.37it/s]
# Epoch 137 of 200
# Generator loss: 1.69719076, Discriminator loss: 0.80039859
# 118it [00:07, 15.45it/s]
# Epoch 138 of 200
# Generator loss: 1.75772989, Discriminator loss: 0.81433976
# 118it [00:07, 15.44it/s]
# Epoch 139 of 200
# Generator loss: 1.64886820, Discriminator loss: 0.87883705
# 118it [00:07, 15.10it/s]
# Epoch 140 of 200
# Generator loss: 1.65520537, Discriminator loss: 0.84325463
# 118it [00:07, 15.42it/s]
# Epoch 141 of 200
# Generator loss: 1.79665256, Discriminator loss: 0.78884822
# 118it [00:07, 15.43it/s]
# Epoch 142 of 200
# Generator loss: 1.78296399, Discriminator loss: 0.78302675
# 118it [00:07, 15.15it/s]
# Epoch 143 of 200
# Generator loss: 1.70936894, Discriminator loss: 0.81063110
# 118it [00:07, 15.26it/s]
# Epoch 144 of 200
# Generator loss: 1.73225486, Discriminator loss: 0.81893027
# 118it [00:07, 15.15it/s]
# Epoch 145 of 200
# Generator loss: 1.78988945, Discriminator loss: 0.81578118
# 118it [00:07, 15.34it/s]
# Epoch 146 of 200
# Generator loss: 1.77722943, Discriminator loss: 0.79400241
# 118it [00:07, 15.49it/s]
# Epoch 147 of 200
# Generator loss: 1.68354976, Discriminator loss: 0.84269589
# 118it [00:07, 15.17it/s]
# Epoch 148 of 200
# Generator loss: 1.67537415, Discriminator loss: 0.82822168
# 118it [00:07, 15.12it/s]
# Epoch 149 of 200
# Generator loss: 1.75125253, Discriminator loss: 0.79254359
# 118it [00:07, 15.57it/s]
# Epoch 150 of 200
# Generator loss: 1.62420619, Discriminator loss: 0.84298825
# 118it [00:07, 15.44it/s]
# Epoch 151 of 200
# Generator loss: 1.69112158, Discriminator loss: 0.83499730
# 118it [00:07, 15.40it/s]
# Epoch 152 of 200
# Generator loss: 1.65640712, Discriminator loss: 0.83276147
# 118it [00:07, 15.17it/s]
# Epoch 153 of 200
# Generator loss: 1.59579825, Discriminator loss: 0.87432361
# 118it [00:07, 15.37it/s]
# Epoch 154 of 200
# Generator loss: 1.77199078, Discriminator loss: 0.78960866
# 118it [00:07, 15.29it/s]
# Epoch 155 of 200
# Generator loss: 1.64312720, Discriminator loss: 0.83076984
# 118it [00:07, 15.11it/s]
# Epoch 156 of 200
# Generator loss: 1.68823755, Discriminator loss: 0.80014950
# 118it [00:07, 15.21it/s]
# Epoch 157 of 200
# Generator loss: 1.68979323, Discriminator loss: 0.81757402
# 118it [00:07, 14.98it/s]
# Epoch 158 of 200
# Generator loss: 1.65439475, Discriminator loss: 0.83286119
# 118it [00:07, 15.38it/s]
# Epoch 159 of 200
# Generator loss: 1.75302696, Discriminator loss: 0.83417743
# 118it [00:07, 15.58it/s]
# Epoch 160 of 200
# Generator loss: 1.65122485, Discriminator loss: 0.87636507
# 118it [00:07, 15.48it/s]
# Epoch 161 of 200
# Generator loss: 1.68305802, Discriminator loss: 0.85492396
# 118it [00:07, 15.30it/s]
# Epoch 162 of 200
# Generator loss: 1.65549600, Discriminator loss: 0.81562257
# 118it [00:07, 15.05it/s]
# Epoch 163 of 200
# Generator loss: 1.72492135, Discriminator loss: 0.80938703
# 118it [00:07, 15.17it/s]
# Epoch 164 of 200
# Generator loss: 1.67387354, Discriminator loss: 0.86351204
# 118it [00:07, 15.43it/s]
# Epoch 165 of 200
# Generator loss: 1.60850191, Discriminator loss: 0.85123730
# 118it [00:07, 15.30it/s]
# Epoch 166 of 200
# Generator loss: 1.70953202, Discriminator loss: 0.81068838
# 118it [00:07, 15.40it/s]
# Epoch 167 of 200
# Generator loss: 1.68465805, Discriminator loss: 0.82044840
# 118it [00:07, 15.58it/s]
# Epoch 168 of 200
# Generator loss: 1.62892950, Discriminator loss: 0.83548540
# 118it [00:07, 15.52it/s]
# Epoch 169 of 200
# Generator loss: 1.61028934, Discriminator loss: 0.87028968
# 118it [00:07, 15.19it/s]
# Epoch 170 of 200
# Generator loss: 1.69310558, Discriminator loss: 0.83999884
# 118it [00:07, 15.52it/s]
# Epoch 171 of 200
# Generator loss: 1.64822602, Discriminator loss: 0.85604161
# 118it [00:07, 15.21it/s]
# Epoch 172 of 200
# Generator loss: 1.64926803, Discriminator loss: 0.81190079
# 118it [00:07, 15.65it/s]
# Epoch 173 of 200
# Generator loss: 1.67364812, Discriminator loss: 0.84534574
# 118it [00:07, 15.15it/s]
# Epoch 174 of 200
# Generator loss: 1.63822210, Discriminator loss: 0.86060458
# 118it [00:07, 15.38it/s]
# Epoch 175 of 200
# Generator loss: 1.63555884, Discriminator loss: 0.85195661
# 118it [00:07, 15.49it/s]
# Epoch 176 of 200
# Generator loss: 1.60867178, Discriminator loss: 0.84772110
# 118it [00:07, 15.56it/s]
# Epoch 177 of 200
# Generator loss: 1.61605370, Discriminator loss: 0.84565353
# 118it [00:07, 15.42it/s]
# Epoch 178 of 200
# Generator loss: 1.65301847, Discriminator loss: 0.82696015
# 118it [00:07, 15.04it/s]
# Epoch 179 of 200
# Generator loss: 1.64019167, Discriminator loss: 0.85307866
# 118it [00:07, 15.59it/s]
# Epoch 180 of 200
# Generator loss: 1.69652498, Discriminator loss: 0.85521680
# 118it [00:07, 15.60it/s]
# Epoch 181 of 200
# Generator loss: 1.67135930, Discriminator loss: 0.81419688
# 118it [00:07, 15.53it/s]
# Epoch 182 of 200
# Generator loss: 1.68065703, Discriminator loss: 0.84962082
# 118it [00:07, 15.09it/s]
# Epoch 183 of 200
# Generator loss: 1.63525343, Discriminator loss: 0.85249990
# 118it [00:07, 15.57it/s]
# Epoch 184 of 200
# Generator loss: 1.65034068, Discriminator loss: 0.82086664
# 118it [00:07, 15.55it/s]
# Epoch 185 of 200
# Generator loss: 1.76549280, Discriminator loss: 0.78855044
# 118it [00:07, 15.51it/s]
# Epoch 186 of 200
# Generator loss: 1.68220079, Discriminator loss: 0.83853507
# 118it [00:07, 15.23it/s]
# Epoch 187 of 200
# Generator loss: 1.75531721, Discriminator loss: 0.83350819
# 118it [00:07, 15.30it/s]
# Epoch 188 of 200
# Generator loss: 1.65836060, Discriminator loss: 0.82911575
# 118it [00:07, 15.55it/s]
# Epoch 189 of 200
# Generator loss: 1.65325439, Discriminator loss: 0.84971005
# 118it [00:07, 15.42it/s]
# Epoch 190 of 200
# Generator loss: 1.61100447, Discriminator loss: 0.85288978
# 118it [00:07, 15.46it/s]
# Epoch 191 of 200
# Generator loss: 1.53834915, Discriminator loss: 0.88575017
# 118it [00:07, 15.37it/s]
# Epoch 192 of 200
# Generator loss: 1.68949020, Discriminator loss: 0.84054756
# 118it [00:07, 15.62it/s]
# Epoch 193 of 200
# Generator loss: 1.62529004, Discriminator loss: 0.85797626
# 118it [00:07, 15.54it/s]
# Epoch 194 of 200
# Generator loss: 1.71038783, Discriminator loss: 0.85586029
# 118it [00:07, 15.22it/s]
# Epoch 195 of 200
# Generator loss: 1.65777922, Discriminator loss: 0.85682744
# 118it [00:07, 15.39it/s]
# Epoch 196 of 200
# Generator loss: 1.65031946, Discriminator loss: 0.84244990
# 118it [00:07, 15.43it/s]
# Epoch 197 of 200
# Generator loss: 1.59077132, Discriminator loss: 0.86437863
# 118it [00:07, 15.27it/s]
# Epoch 198 of 200
# Generator loss: 1.72537541, Discriminator loss: 0.86155444
# 118it [00:07, 15.37it/s]
# Epoch 199 of 200
# Generator loss: 1.68923986, Discriminator loss: 0.85531092
# DONE TRAINING
